# %% [markdown]
# <a href="https://colab.research.google.com/github/chuter176/Exercise_2025/blob/main/124def_125arameter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# def

# %%
def displayFilepath():
  filepath = 'c:/myworks/pythonstrudy.py'
  print(f'파일경로:{filepath}')
  return


displayFilepath()
# Out:
# 파일경로:c:/myworks/pythonstrudy.py

# %%
def printFilepath(folder,filename):
  print(f'파일경로:{folder+filename}')
  return

printFilepath('c:/myworks/','pythonstudy.py')
# Out:
# 파일경로:c:/myworks/pythonstudy.py

# %%
def getFilepath():
   filepath = 'c:/myworks/pythonstrudy.py'
   return filepath

filepath = getFilepath()
print(f'파일경로:{filepath}')
# Out:
# 파일경로:c:/myworks/pythonstrudy.py

# %%
def makeFilepath(folder,filename):
  return folder+filename

filepath = makeFilepath('c:/myworks/','pythonstudy.py')
print(f'파일경로:{filepath}')
# Out:
# 파일경로:c:/myworks/pythonstudy.py

# %% [markdown]
# arameter

# %%
def setLevel(character,level=1):
  print(f'{character}의 레벨:{level}')
  return

# %%
setLevel('유비')
setLevel('제괄량',10)
# Out:
# 유비의 레벨:1
# 제괄량의 레벨:10

# %%
def setLevel(level=1,character):
# Out:
#   File "/tmp/ipython-input-2410855618.py", line 1
#     def setLevel(level=1,character):
#                          ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def setLevel(character,level=1):
  print(f'{character}의 레벨:{level}')
  return

# %%
setLevel(level=5,character='장비')
# Out:
# 장비의 레벨:5

# %%
def setLevel(*args):
  print(args)
  return

# %%
setLevel('관우',7)
setLevel('조운','named',10)
# Out:
# ('관우', 7)
# ('조운', 'named', 10)

# %%
def setLevel(**kwargs):
  print(kwargs)
  return

# %%
setLevel(character='조운',level=10)
setLevel(character='황충',category='named',level=5)
# Out:
# {'character': '조운', 'level': 10}
# {'character': '황충', 'category': 'named', 'level': 5}

# %%
def setLevel(character,level,*args):
  print(f'장수:{character},레벨:{level}')
  if len(args) != 0:
    print(f'기타 특성:{args}')
  return

# %%
setLevel('조조',3)
# Out:
# 장수:조조,레벨:3

# %%
setLevel('유비',3,'named','leader')
# Out:
# 장수:유비,레벨:3
# 기타 특성:('named', 'leader')

# %%
def setLevel(character,level,**kwargs):
  print(f'장수:{character},레벨:{level}')
  if len(kwargs) != 0:
    for k,v in kwargs.items():
      print(f'{k}:{v}')
  return

# %%
setLevel('조조',3)
# Out:
# 장수:조조,레벨:3

# %%
setLevel('유비',3,category='named',position ='leader')
# Out:
# 장수:유비,레벨:3
# category:named
# position:leader
