# %% [markdown]
# <a href="https://colab.research.google.com/github/chuter176/Exercise_2025/blob/main/112key%20not%20in%20d_113iter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# key not in d

# %%
frequency = {}
while True:
  c = input('알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:')
  if c == '':
    break
  if c not in frequency:
    frequency[c] = 1
  else:
    frequency[c] += 1
  print(frequency)
# Out:
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:v
# {'v': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:

# %% [markdown]
# iter

# %%
greats = {'유비':89,'관우':95,'장비':91,'조운':94}
for name in iter(greats):
  print(name)
# Out:
# 유비
# 관우
# 장비
# 조운
