# %% [markdown]
# <a href="https://colab.research.google.com/github/chuter176/Exercise_2025/blob/main/116d.items_117d.keys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# d.items

# %%
greats = {'유비':89,'관우':95,'장비':91,'조운':94}
generals = greats.items()
print(list(generals))
# Out:
# [('유비', 89), ('관우', 95), ('장비', 91), ('조운', 94)]

# %%
del greats['관우']
print(list(generals))
# Out:
# [('유비', 89), ('장비', 91), ('조운', 94)]

# %% [markdown]
# d.keys

# %%
greats = {'유비':89,'관우':95,'장비':91,'조운':94}
general_names = greats.keys()
print(list(general_names))
# Out:
# ['유비', '관우', '장비', '조운']

# %%
del greats['관우']
for i, name in enumerate(general_names, start=1):
  print(f'남아 있는 촉나라 장수[{i}]:{name}')
# Out:
# 남아 있는 촉나라 장수[1]:유비
# 남아 있는 촉나라 장수[2]:장비
# 남아 있는 촉나라 장수[3]:조운
