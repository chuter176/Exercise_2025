# %% [markdown]
# <a href="https://colab.research.google.com/github/chuter176/Exercise_2025/blob/main/110del%20d%5Bkey%5D_111key%20in%20d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# del d[key]

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
del names['Mary']
print(names)
# Out:
# {'Cris': 2111, 'Aimy': 9778, 'Tom': 20245}

# %%
del names['Sams']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3085454307.py in <cell line: 0>()
# ----> 1 del names['Sams']
#
# KeyError: 'Sams'

# %% [markdown]
# key in d

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
name = input('이름을 입력하세요:')
if name in names:
  print(f'이름이<{name}>인 출생아수는 <{names[name]:,d}>명입니다.')
else:
   print(f'딕셔너리 names에 <{name}>인 이름이 존재하지 않습니다.')
# Out:
# 이름을 입력하세요:Mary
# 이름이<Mary>인 출생아수는 <10,999>명입니다.
