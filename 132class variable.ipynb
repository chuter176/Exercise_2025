# %% [markdown]
# <a href="https://colab.research.google.com/github/chuter176/Exercise_2025/blob/main/132class%20variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# class variable

# %%
class Wizard:
  generated = 0

  def __init__(self):
    Wizard.generated += 1
    self.name = name
    self.level = 1
    self.hp = 100
    self.initAbility()

  def initAbility(self):
    self.strength = 1
    self.offense_power = 1
    self.intelligence = 10
    self.menrality = 10
    self.agility = 1

# %%
player
